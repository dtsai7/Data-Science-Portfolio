# %% [markdown]
# For this project, I will analyze YouBike dataset provided by New Taipei City Government.
#   (https://data.gov.tw/dataset/28318)
#
#
# The data contains the following fields: (I translated all into English)
#
#
#
# | Columns Name | Description|
# |------|------|
# | sno |ID number of YouBike Station|
# | sna |Chinese Station Name|
# | tot |Station Total Parking Space|
# | sbi |Number of availble YouBikes|
# | sarea|Chinese Station Area|
# | mday|Data Update Time|
# | lat|Latitude|
# | lng|Longtitude|
# | ar|Chinese Address|
# | sareaen|English Station Area|
# | snaen|English Station Name|
# | aren|English Address|
# | bemp|Available Parking Space|
# | act|Whether the station is in operation or not|
#
#
# Let's import libraries first

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('/Users/David_Tsai/Downloads/youbike.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 14 columns):
# sno        548 non-null int64
# sna        548 non-null object
# tot        548 non-null int64
# sbi        548 non-null int64
# sarea      548 non-null object
# mday       548 non-null int64
# lat        548 non-null float64
# lng        548 non-null float64
# ar         548 non-null object
# sareaen    548 non-null object
# snaen      548 non-null object
# aren       547 non-null object
# bemp       548 non-null int64
# act        548 non-null int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 60.0+ KB

# %%
df.describe()
# Out:
#                sno         tot         sbi          mday         lat  \
# count   548.000000  548.000000  548.000000  5.480000e+02  548.000000
# mean   1282.051095   40.521898   16.786496  2.019060e+13   25.030206
# std     171.104213   10.863179    9.834649  2.387265e+07    0.054336
# min    1001.000000   26.000000    0.000000  2.019022e+13   24.907449
# 25%    1137.750000   34.000000   10.000000  2.019060e+13   24.991696
# 50%    1274.500000   38.000000   16.000000  2.019060e+13   25.021140
# 75%    1417.250000   44.000000   22.000000  2.019060e+13   25.066675
# max    1648.000000  106.000000   64.000000  2.019060e+13   25.201250
#
#               lng        bemp         act
# count  548.000000  548.000000  548.000000
# mean   121.470825   23.016423    0.990876
# std      0.069746   10.563887    0.095170
# min    121.330254    0.000000    0.000000
# 25%    121.432823   16.000000    1.000000
# 50%    121.462581   22.000000    1.000000
# 75%    121.496704   29.000000    1.000000
# max    121.810410   81.000000    1.000000

# %%
df.head()
# Out:
#     sno     sna  tot  sbi sarea            mday        lat         lng  \
# 0  1001    大鵬華城   38   14   新店區  20190604111321  24.991160  121.533980
# 1  1002   汐止火車站   56   26   汐止區  20190604111335  25.068914  121.662748
# 2  1003   汐止區公所   46   19   汐止區  20190604111332  25.064162  121.658301
# 3  1004  國泰綜合醫院   56    5   汐止區  20190604111337  25.073150  121.662555
# 4  1005    裕隆公園   40   13   新店區  20190604111336  24.979649  121.546319
#
#                                 ar        sareaen                    snaen  \
# 0                  新北市新店區中正路700巷3號  Xindian Dist.         Dapeng Community
# 1                   南昌街/新昌路口(西側廣場)    Xizhi Dist.    Xizhi Railway Station
# 2  新台五路一段/仁愛路口(新台五路側汐止地政事務所前機車停車場)    Xizhi Dist.       Xizhi Dist. Office
# 3                      建成路78號對面停車場    Xizhi Dist.  Cathay General Hospital
# 4                    寶中路/品牌路口(東南側)  Xindian Dist.               Yulon Park
#
#                                                 aren  bemp  act
# 0  No. 3, Lane 700 Chung Cheng Road, Xindian Dist...    24    1
# 1                          Nanchang St./Xinchang Rd.    30    1
# 2                  Sec. 1, Xintai 5th Rd./Ren’ai Rd.    27    1
# 3                                 No78, Jiancheng Rd    51    1
# 4                                      Baozhong Rd./    26    1

# %% [markdown]
# Check how many stations are still in operation?

# %%
sns.countplot(x= 'act', data= df)

# %% [markdown]
# Draw a boxplot of variables that I want to analyze more

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data=df[['tot','sbi', 'bemp']])

# %% [markdown]
# Then do more data visualization

# %%
plt.figure(figsize=(15, 8))
tot = sns.countplot(x="tot", data=df)

# %% [markdown]
# How about the number of available YouBikes?

# %%
plt.figure(figsize=(15, 8))
tot = sns.countplot(x='sbi', data=df)

# %% [markdown]
# Then let's combine these two with joint plot.

# %%
sns.jointplot(x="tot", y="sbi", data= df, kind ='reg', height = 10)

# %% [markdown]
# What if we take district into consideration?

# %%
sns.relplot(x= 'tot', y= 'sbi', hue = 'sareaen', data = df, height = 10)

# %% [markdown]
# Speaking of distirct, let's see how many stations for each district in New Taipei City!

# %%
area_table = pd.DataFrame(df.groupby(['sarea']).sum())
area_table = area_table[['tot','sbi', 'bemp', 'act']]
area_table['new_col'] = range(1, len(area_table) + 1)
area_table = area_table.reset_index()
area_table.rename(columns={'sarea': 'TOWNNAME'}, inplace=True)
area_table = area_table[['TOWNNAME','tot','sbi', 'bemp', 'act']]
area_table
# Out:
#    TOWNNAME   tot   sbi  bemp  act
# 0       三峽區   676   323   349   17
# 1       三重區  2420   996  1400   59
# 2       中和區  1712   793   850   42
# 3       五股區   572   221   311   15
# 4       八里區   188    72   116    5
# 5       土城區  1212   619   592   31
# 6       新店區  1662   785   860   43
# 7       新莊區  2280   858  1415   55
# 8       板橋區  3604  1407  2119   84
# 9       林口區   972   356   573   24
# 10      樹林區  1152   495   650   31
# 11      永和區   976   446   514   25
# 12      汐止區  1468   478   983   32
# 13      泰山區   402   191   205   11
# 14      淡水區   996   444   545   24
# 15      深坑區    84    31    53    2
# 16      瑞芳區   118    39    79    3
# 17      蘆洲區  1080   396   674   25
# 18      鶯歌區   632   249   325   15

# %% [markdown]
# In order to plot the result on the map, we need to import geopandas and the map of Taiwan.

# %%
import geopandas as gp
villages_shp = gp.read_file('/Users/David_Tsai/Downloads/map/TOWN_MOI_1080509.shp') #map of Taiwan
newtaipei_shp = villages_shp.query('COUNTYNAME=="新北市"') #map of New Taipei City

# %%
newtaipei_shp.head()
# Out:
#     TOWNID  TOWNCODE COUNTYNAME TOWNNAME           TOWNENG COUNTYID  \
# 213    F33  65000040        新北市      永和區   Yonghe District        F
# 214    F07  65000060        新北市      新店區  Xindian District        F
# 215    F19  65000130        新北市      土城區  Tucheng District        F
# 216    F04  65000140        新北市      蘆洲區   Luzhou District        F
# 217    F03  65000150        新北市      五股區     Wugu District        F
#
#     COUNTYCODE                                           geometry
# 213      65000  POLYGON ((121.5123947940001 25.02174595900004,...
# 214      65000  POLYGON ((121.6092225440001 24.96401839600009,...
# 215      65000  POLYGON ((121.4671417850001 24.99298475300009,...
# 216      65000  POLYGON ((121.491140105 25.09476749800007, 121...
# 217      65000  POLYGON ((121.4590200780001 25.11272426200009,...

# %% [markdown]
# Merge two tables together!

# %%
newtaipei_shp = newtaipei_shp.merge(area_table, left_on='TOWNNAME', right_on = 'TOWNNAME')
newtaipei_shp
# Out:
#    TOWNID  TOWNCODE COUNTYNAME TOWNNAME             TOWNENG COUNTYID  \
# 0     F33  65000040        新北市      永和區     Yonghe District        F
# 1     F07  65000060        新北市      新店區    Xindian District        F
# 2     F19  65000130        新北市      土城區    Tucheng District        F
# 3     F04  65000140        新北市      蘆洲區     Luzhou District        F
# 4     F03  65000150        新北市      五股區       Wugu District        F
# 5     F27  65000100        新北市      淡水區    Danshui District        F
# 6     F21  65000120        新北市      瑞芳區    Ruifang District        F
# 7     F02  65000170        新北市      林口區     Linkou District        F
# 8     F32  65000230        新北市      八里區       Bali District        F
# 9     F15  65000090        新北市      三峽區     Sanxia District        F
# 10    F16  65000080        新北市      鶯歌區     Yingge District        F
# 11    F18  65000030        新北市      中和區    Zhonghe District        F
# 12    F17  65000070        新北市      樹林區     Shulin District        F
# 13    F09  65000180        新北市      深坑區   Shenkeng District        F
# 14    F14  65000010        新北市      板橋區    Banqiao District        F
# 15    F01  65000050        新北市      新莊區  Xinzhuang District        F
# 16    F06  65000160        新北市      泰山區    Taishan District        F
# 17    F05  65000020        新北市      三重區   Sanzhong District        F
# 18    F28  65000110        新北市      汐止區      Xizhi District        F
#
#    COUNTYCODE                                           geometry   tot   sbi  \
# 0       65000  POLYGON ((121.5123947940001 25.02174595900004,...   976   446
# 1       65000  POLYGON ((121.6092225440001 24.96401839600009,...  1662   785
# 2       65000  POLYGON ((121.4671417850001 24.99298475300009,...  1212   619
# 3       65000  POLYGON ((121.491140105 25.09476749800007, 121...  1080   396
# 4       65000  POLYGON ((121.4590200780001 25.11272426200009,...   572   221
# 5       65000  POLYGON ((121.450669045 25.24424598900004, 121...   996   444
# 6       65000  POLYGON ((121.823493854 25.13601305700007, 121...   118    39
# 7       65000  POLYGON ((121.3709369520001 25.12842823900007,...   972   356
# 8       65000  POLYGON ((121.4357293720001 25.16606711400004,...   188    72
# 9       65000  POLYGON ((121.407659574 24.95206866900008, 121...   676   323
# 10      65000  POLYGON ((121.3426856970001 24.98231470000007,...   632   249
# 11      65000  POLYGON ((121.4886834250001 25.01567630600005,...  1712   793
# 12      65000  POLYGON ((121.4125303750001 25.02032064300005,...  1152   495
# 13      65000  POLYGON ((121.632440351 25.02562973300007, 121...    84    31
# 14      65000  POLYGON ((121.4784192090001 25.03983647200005,...  3604  1407
# 15      65000  POLYGON ((121.4620053440001 25.06882662500004,...  2280   858
# 16      65000  POLYGON ((121.3985040480001 25.07668094700006,...   402   191
# 17      65000  POLYGON ((121.491151565 25.09475731400005, 121...  2420   996
# 18      65000  POLYGON ((121.6267893060001 25.13970771600009,...  1468   478
#
#     bemp  act
# 0    514   25
# 1    860   43
# 2    592   31
# 3    674   25
# 4    311   15
# 5    545   24
# 6     79    3
# 7    573   24
# 8    116    5
# 9    349   17
# 10   325   15
# 11   850   42
# 12   650   31
# 13    53    2
# 14  2119   84
# 15  1415   55
# 16   205   11
# 17  1400   59
# 18   983   32

# %%
fig, ax = plt.subplots(1, figsize=(10, 8))
newtaipei_shp.plot(column = 'tot', linewidth=0.8, ax=ax, legend = True)
ax.legend(title = 'Youbike Station Total Parking Space in New Taipei City')
# Out:
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(1, figsize=(10, 8))
newtaipei_shp.plot(column = 'sbi', linewidth=0.8, ax=ax, legend = True)
ax.legend(title = 'Number of Available Youbikes in New Taipei City')
# Out:
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(1, figsize=(10, 8))
newtaipei_shp.plot(column = 'bemp', linewidth=0.8, ax=ax, legend = True)
ax.legend(title = 'Available Parking Space in New Taipei City')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# We can see that:
# 1. There are some districts without YouBikes in New Taipei City (which are not shown on the map).
# 2. There are more youbikes in the district near Taipei City. WE can't tell the reasons right away.
#  However, I guess it's due to the transportation between two cities.

# %% [markdown]
# This data anlysis project ends here.
